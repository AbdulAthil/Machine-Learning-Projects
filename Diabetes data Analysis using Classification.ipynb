# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Read the dataset

# %%
df=pd.read_csv("diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# ## Summarize the data

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.shape
# Out:
# (768, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# ### Check if the dataset has any missing values

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### Find out the total number of pregnencies

# %%
df["Pregnancies"].sum()
# Out:
# 2953

# %% [markdown]
# ### Find out the maximum blood pressure

# %%
df["BloodPressure"].max()
# Out:
# 122

# %% [markdown]
# ### Find out the average BMI value

# %%
df["BMI"].mean()
# Out:
# 31.992578124999998

# %% [markdown]
# ### Find out how many patients are within the age between 50 to 70

# %%
df[(df["Age"]>50)&(df["Age"]<70)].count()
# Out:
# Pregnancies                 78
# Glucose                     78
# BloodPressure               78
# SkinThickness               78
# Insulin                     78
# BMI                         78
# DiabetesPedigreeFunction    78
# Age                         78
# Outcome                     78
# dtype: int64

# %% [markdown]
# ### Find the outcome values

# %%
df["Outcome"].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %% [markdown]
# ### FInd top 5 age group which has maximum numbers of patients

# %%
df["Age"].value_counts().head()
# Out:
# 22    72
# 21    63
# 25    48
# 24    46
# 23    38
# Name: Age, dtype: int64

# %% [markdown]
# ### Find out how many patients outcome is 1 based on their age

# %%
group=df["Outcome"].groupby(df["Age"])
group.sum()
# Out:
# Age
# 21     5
# 22    11
# 23     7
# 24     8
# 25    14
# 26     8
# 27     8
# 28    10
# 29    13
# 30     6
# 31    13
# 32     9
# 33    10
# 34     4
# 35     5
# 36    10
# 37     6
# 38    10
# 39     3
# 40     6
# 41    13
# 42     7
# 43    11
# 44     5
# 45     8
# 46     7
# 47     4
# 48     1
# 49     3
# 50     5
# 51     5
# 52     7
# 53     4
# 54     4
# 55     1
# 56     2
# 57     1
# 58     3
# 59     2
# 60     2
# 61     1
# 62     2
# 63     0
# 64     0
# 65     0
# 66     2
# 67     1
# 68     0
# 69     0
# 70     1
# 72     0
# 81     0
# Name: Outcome, dtype: int64

# %% [markdown]
# ### Find out the average value of DiabetesPedigreeFunction

# %%
df["DiabetesPedigreeFunction"].mean()
# Out:
# 0.47187630208333325

# %% [markdown]
# ## Exploratory Data Analysis

# %%
fig,ax=plt.subplots(ncols=1,nrows=9,figsize=(5,30))
index=0
ax=ax.flatten()

for col in df:
    sns.distplot(df[col],ax=ax[index])
    index+=1
    
plt.show()

# %% [markdown]
# ### Draw countplot for outcome

# %%
sns.countplot(x="Outcome",data=df)
plt.show()

# %% [markdown]
# ### Coorelation Matrix

# %%
plt.figure(figsize=(8,6))
corr=df.corr()
sns.heatmap(corr,annot=True)
plt.show()

# %% [markdown]
# ### Create a pairplot for the dataset

# %%
sns.pairplot(df)

# %% [markdown]
# ## Split the data into train and test

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
x=df.drop(columns=["Outcome"],axis=1)
x
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
y=df["Outcome"]
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=1)

# %%
print("x_train:",x_train.shape)
print("x_test:",x_test.shape)
print("y_train:",y_train.shape)
print("y_test:",y_test.shape)
# Out:
# x_train: (576, 8)
# x_test: (192, 8)
# y_train: (576,)
# y_test: (192,)

# %% [markdown]
# ## Model Building

# %%
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# %%
models=[]
scores=[]

def classify(model,x,y):
    model.fit(x_train,y_train)
    #prediction
    y_predict=model.predict(x_test)
    #Evaluation
    #Accuracy
    Accuracy=model.score(x_test,y_test)*100
    print("Accuracy is:",Accuracy,"\n")
    #Cross Validation
    score=cross_val_score(model,x,y,cv=5)
    print("Cross validation score:",np.mean(score)*100,"\n")
    #Classification Report
    report=metrics.classification_report(y_test,y_predict)
    print("Classification Report:\n",report,"\n")
    #Confusion Matrix
    matrix=metrics.confusion_matrix(y_test,y_predict)
    print("Confusion Matrix:\n",matrix,"\n")
    #Heatmap for confusion matrix
    plt.figure(figsize=(4,3))
    sns.heatmap(matrix,annot=True)
    plt.show()
    
    models.append(model)
    scores.append(Accuracy)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
classify(model,x,y)
# Out:
# Accuracy is: 77.60416666666666
#
# Cross validation score: 77.08768355827178
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.89      0.84       123
#            1       0.74      0.58      0.65        69
#
#     accuracy                           0.78       192
#    macro avg       0.77      0.73      0.74       192
# weighted avg       0.77      0.78      0.77       192
#
#
# Confusion Matrix:
#  [[109  14]
#  [ 29  40]]

# %%
from sklearn.neighbors import KNeighborsClassifier
#Error Rate
error_rate=[]
for i in range(1,20):
    model=KNeighborsClassifier(n_neighbors=i)
    model.fit(x_train,y_train)
    y_predict=model.predict(x_test)
    error_rate.append(np.mean(y_predict!=y_test))

# %%
#Error rate vs K-values

plt.figure(figsize=(10,6))
plt.plot(range(1,20),error_rate,color="blue",marker="o",mfc="red",markersize=10)
plt.title("Error Rate vs K-values")
plt.xlabel("K-values")
plt.ylabel("Error Rate")
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier(n_neighbors=13)
classify(model,x,y)
# Out:
# Accuracy is: 78.64583333333334
#
# Cross validation score: 75.5258467023173
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.88      0.84       123
#            1       0.74      0.62      0.68        69
#
#     accuracy                           0.79       192
#    macro avg       0.77      0.75      0.76       192
# weighted avg       0.78      0.79      0.78       192
#
#
# Confusion Matrix:
#  [[108  15]
#  [ 26  43]]

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
classify(model,x,y)
# Out:
# Accuracy is: 69.27083333333334
#
# Cross validation score: 70.06960359901538
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.74      0.80      0.77       123
#            1       0.59      0.49      0.54        69
#
#     accuracy                           0.69       192
#    macro avg       0.66      0.65      0.65       192
# weighted avg       0.68      0.69      0.69       192
#
#
# Confusion Matrix:
#  [[99 24]
#  [35 34]]

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier(n_estimators=100)
classify(model,x,y)
# Out:
# Accuracy is: 81.25
#
# Cross validation score: 76.43748408454292
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.90      0.86       123
#            1       0.79      0.65      0.71        69
#
#     accuracy                           0.81       192
#    macro avg       0.81      0.78      0.79       192
# weighted avg       0.81      0.81      0.81       192
#
#
# Confusion Matrix:
#  [[111  12]
#  [ 24  45]]

# %%
from sklearn.ensemble import ExtraTreesClassifier
model=ExtraTreesClassifier()
classify(model,x,y)
# Out:
# Accuracy is: 77.60416666666666
#
# Cross validation score: 76.95951107715814
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.88      0.83       123
#            1       0.73      0.59      0.66        69
#
#     accuracy                           0.78       192
#    macro avg       0.76      0.74      0.74       192
# weighted avg       0.77      0.78      0.77       192
#
#
# Confusion Matrix:
#  [[108  15]
#  [ 28  41]]

# %%
from sklearn.svm import SVC
model=SVC(kernel="linear")
classify(model,x,y)
# Out:
# Accuracy is: 78.125
#
# Cross validation score: 76.56820303879128
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.88      0.84       123
#            1       0.74      0.61      0.67        69
#
#     accuracy                           0.78       192
#    macro avg       0.77      0.74      0.75       192
# weighted avg       0.78      0.78      0.78       192
#
#
# Confusion Matrix:
#  [[108  15]
#  [ 27  42]]

# %%
from xgboost import XGBClassifier
model=XGBClassifier()
classify(model,x,y)
# Out:
# Accuracy is: 75.52083333333334
#
# Cross validation score: 74.09557762498939
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81       123
#            1       0.66      0.65      0.66        69
#
#     accuracy                           0.76       192
#    macro avg       0.73      0.73      0.73       192
# weighted avg       0.75      0.76      0.75       192
#
#
# Confusion Matrix:
#  [[100  23]
#  [ 24  45]]

# %%
print(models)
print(scores)
# Out:
# [LogisticRegression(), KNeighborsClassifier(n_neighbors=13), DecisionTreeClassifier(), RandomForestClassifier(), ExtraTreesClassifier(), SVC(kernel='linear'), XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)]
# ...

# %%
plt.figure(figsize=(10,6))
a=[1,2,3,4,5,6,7]
colors=["Skyblue","pink","grey","cyan","lightgreen","yellow","purple"]
plt.bar(a,scores,color=colors,width=0.5)
plt.plot(a,scores,lw=0.5,color="green",marker="o",ms=8,mfc="red")
plt.title("Model Comparision")
print(f'{models[0]} : ',scores[0])
print(f'{models[1]} : ',scores[1])
print(f'{models[2]} : ',scores[2])
print(f'{models[3]} : ',scores[3])
print(f'{models[4]} : ',scores[4])
print(f'{models[5]} : ',scores[5])
print("XBGClassifier : ",scores[6])
# Out:
# LogisticRegression() :  77.60416666666666
# KNeighborsClassifier(n_neighbors=13) :  78.64583333333334
# DecisionTreeClassifier() :  69.27083333333334
# RandomForestClassifier() :  81.25
# ExtraTreesClassifier() :  77.60416666666666
# SVC(kernel='linear') :  78.125
# XBGClassifier :  75.52083333333334

# %% [markdown]
# From the above comparision we can see that the RandomForestClassifier gives us more accuracy than the other models

# %% [markdown]
# ## Hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
param_grid={"n_estimators":[10,50,100,150,200]}

rf_classifier = RandomForestClassifier()

grid_search=GridSearchCV(estimator=rf_classifier,param_grid=param_grid,cv=5)
grid_search.fit(x_train,y_train)

best_n_estimators=grid_search.best_params_["n_estimators"]
print("best_n_estimator : ",best_n_estimators)

y_pred=grid_search.predict(x_test)

#Accuracy
accuracy=grid_search.score(x_test,y_test)
print("Accuracy is : ",accuracy*100)
#classification report
report=metrics.classification_report(y_test,y_pred)
print("Classification Report :\n\n",report)
#Confusion Matrix
matrix=metrics.confusion_matrix(y_test,y_pred)
print("Confusion Matrix:\n",matrix)
# Out:
# best_n_estimator :  200
# Accuracy is :  81.77083333333334
# Classification Report :
#
#                precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86       123
#            1       0.78      0.68      0.73        69
#
#     accuracy                           0.82       192
#    macro avg       0.81      0.79      0.80       192
# weighted avg       0.82      0.82      0.81       192
#
# Confusion Matrix:
#  [[110  13]
#  [ 22  47]]

# %% [markdown]
# After hyperparameter Tuning,we can see that the accuracy of RandomForestClassifier model slightly increases.
